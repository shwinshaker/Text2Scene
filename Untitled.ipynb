# %%
import numpy as np
import random
np.random.seed(7)
random.seed(7)

from models.dataset import Dataset, DatasetReality
from models.pipeline import prep_data
from ana.visual import STAT, ROC, FEAT
from sklearn.linear_model import LogisticRegression

import warnings
warnings.simplefilter('ignore')

# %%
dataset_r, X_r, y_r, pairs_r, index_r = prep_data(DatasetReality, shuffle_interval=2)
# Out:
# [92]
# Shape (184, 311)

# %%
# higher class weight of 0 will always make it easier in term of precision
# because of imbalance
clf_r = LogisticRegression(# random_state=0,
                           solver='liblinear',
                           class_weight={1: 1, 0:1},
                           penalty='l1', #'l2' use l1 to learn sparsely
                           C=1.0,
                           max_iter=1000)

interval = 2
ind_test = int(X_r.shape[0]/interval * 0.9) * interval
print('# train: ', ind_test)
print('# test: ', X_r.shape[0] - ind_test)
clf_r.fit(X_r[:ind_test], y_r[:ind_test])
# clf.fit(X, y)
y_true = y_r[ind_test:]
y_prob = clf_r.predict_proba(X_r[ind_test:])[:,1]

suffix = 'temp'
STAT(y_true, y_prob, path='realitySTAT_%s' % suffix)
ROC(y_true, y_prob, path='realityROC_%s' % suffix)
FEAT(dataset_r, clf_r, path='realityFEAT_%s' % suffix)
# Out:
# # train:  164
# # test:  20
# 10 positives out of 20 test examples
# Overall accuracy: 0.850000
# *Recall(thresh=0.5)/AccuracyOf1: 0.700000
# Precision(thresh=0.5): 1.000000
# AccuracyOf0(thresh=0.5): 1.000000
# precision | recall | F1 | threshold
# ------------------------------
# 0.769 | 1.000 | 0.870 | 0.047
# 0.750 | 0.900 | 0.818 | 0.110
# 0.900 | 0.900 | 0.900 | 0.362
# 0.889 | 0.800 | 0.842 | 0.440
# 0.875 | 0.700 | 0.778 | 0.464
# 1.000 | 0.700 | 0.824 | 0.683
# 1.000 | 0.600 | 0.750 | 0.717
# 1.000 | 0.500 | 0.667 | 0.854
# 1.000 | 0.400 | 0.571 | 0.913
# 1.000 | 0.300 | 0.462 | 0.933
# 1.000 | 0.200 | 0.333 | 0.959
# 1.000 | 0.100 | 0.182 | 0.997
# ------------------------------
