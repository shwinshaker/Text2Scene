# %%
import numpy as np
import glob
import random
from scipy import sparse

from tools.text_process import LemmaTokenizer
from tools.image_process import getLayerNames, checkLayerNames, image2feature
from models.vectorizer import getVectorizer

# Similarity between category keywords and the description
# suppress cats not in image??**
from tools.image_process import image2SimiFeature

# random image generator, subject to rules
from tools.generator import ranGenLayer

class Dataset():
    def __init__(self, img_dir='images', txt_dir='text'):
        self.img_dir = img_dir
        self.txt_dir = txt_dir
        self.tokenizer = LemmaTokenizer()
        # this operation will process all the text and train a vectorizer
        # so we have double processed the text here
        self.vectorizer = getVectorizer()
        
        # set features
        self.__get_featureNames()
      
    def getOneLayerSent(self, txt_name=None, img_name=None,
                              ran_txt=False, ran_img=False,
                              fake_img=False):
        ##### preprocess
        ## text
        if ran_txt:
            all_txt = glob.glob(self.txt_dir+'/*.txt')
            # rule out current text
            all_txt.remove(txt_name)
            txt_name = random.choice(all_txt)
        else:
            assert(txt_name)
            
        with open(txt_name, 'r') as f:
            orig_sent = f.read()
            sent = self.tokenizer(orig_sent)
            
        ## image
        if ran_img:
            assert img_name
            assert not fake_img
            all_img = glob.glob(self.img_dir+'/*.svg')
            all_img.remove(img_name)
            img_name = random.choice(all_img)
            layers = getLayerNames(img_name)
        elif fake_img:
            assert img_name is None
            assert not ran_img
            layers = ranGenLayer()
        else:
            layers = getLayerNames(img_name)
            
        return layers, sent
    
    def __getEmbed(self, **kwargs):
        
        layers, sent = self.getOneLayerSent(**kwargs)
        
        # tofeature
        txt_embed = self.vectorizer.transform([sent]).toarray()[0]
        img_embed = image2feature(layers)
        joint_embed = image2SimiFeature(layers, sent)
        
        return np.hstack([txt_embed, img_embed, joint_embed])        
    
    def __getitem__(self, ind):
        img_name = '%s/%i.svg' % (self.img_dir, ind+1)
        txt_name = '%s/%i.txt' % (self.txt_dir, ind+1)
        
        # triplets
        triplets = []
        # true match
        triplets.append(self.__getEmbed(txt_name=txt_name,
                                        img_name=img_name))
        # fake image
        triplets.append(self.__getEmbed(txt_name=txt_name,
                                        fake_img=True))
        # mismatched text
        triplets.append(self.__getEmbed(img_name=img_name,
                                        txt_name=txt_name,
                                        ran_txt=True))
        # mismatched image
        triplets.append(self.__getEmbed(img_name=img_name,
                                        txt_name=txt_name,
                                        ran_img=True))
        
        xs = np.vstack(triplets)
        
        # ys
        ys = np.array([1,0,0,0]).reshape(-1,1)
        
        return sparse.csr_matrix(np.hstack([xs, ys]))

    
    def __len__(self):
        return len(glob.glob(self.img_dir+'/*.svg'))
    
    def __get_featureNames(self):
        self.features_ = []
        # text features
        self.vocab_, _ = zip(*sorted(self.vectorizer.vocabulary_.items(),
                                     key=lambda x:x[::-1]))
        self.features_.extend(list(self.vocab_))

        # image features
        from tools.image_process import getNestedKey
        from rules.category import surrouding_dict, person_dict
        self.features_.append('_NLayers_')
        self.features_.extend(['_Background_',
                               '_Surroundings_',
                               '_Person_',
                               '_Decoration_'])
        srd_keys = getNestedKey(surrouding_dict)
        prs_keys = getNestedKey(person_dict)
        self.features_.extend(['_S_%s_' % k for k in srd_keys])
        self.features_.extend(['_P_%s_' % k for k in prs_keys])

        # joint features
        self.features_.extend(['_simi_S_%s_' % k for k in srd_keys])
        self.features_.extend(['_simi_P_%s_' % k for k in prs_keys])

# %%
import numpy as np
import glob
import random
from scipy import sparse

from tools.text_process import LemmaTokenizer
from tools.image_process import getLayerNames, checkLayerNames, image2feature
from models.vectorizer import getVectorizer

# Similarity between category keywords and the description
# suppress cats not in image??**
from tools.image_process import image2SimiFeature

# random image generator, subject to rules
from tools.generator import ranGenLayer

class Dataset():
    def __init__(self, img_dir='images', txt_dir='text'):
        self.img_dir = img_dir
        self.txt_dir = txt_dir
        self.tokenizer = LemmaTokenizer()
        # this operation will process all the text and train a vectorizer
        # so we have double processed the text here
        self.vectorizer = getVectorizer()
        
        # set features
        self.__get_featureNames()
      
    def getOneLayerSent(self, txt_name=None, img_name=None,
                              ran_txt=False, ran_img=False,
                              fake_img=False):
        ##### preprocess
        ## text
        if ran_txt:
            all_txt = glob.glob(self.txt_dir+'/*.txt')
            # rule out current text
            all_txt.remove(txt_name)
            txt_name = random.choice(all_txt)
        else:
            assert(txt_name)
            
        with open(txt_name, 'r') as f:
            orig_sent = f.read()
            sent = self.tokenizer(orig_sent)
            
        ## image
        if ran_img:
            assert img_name
            assert not fake_img
            all_img = glob.glob(self.img_dir+'/*.svg')
            all_img.remove(img_name)
            img_name = random.choice(all_img)
            layers = getLayerNames(img_name)
        elif fake_img:
            assert img_name is None
            assert not ran_img
            layers = ranGenLayer()
        else:
            layers = getLayerNames(img_name)
            
        return layers, sent
    
    def __flattenSparse(self, matrix):
        return matrix.toarray().flatten()
        
    def __getEmbed(self, **kwargs):
        
        layers, sent = self.getOneLayerSent(**kwargs)
        
        # tofeature
        txt_embed = self.vectorizer.transform([sent]).toarray()[0]
        img_embed = image2feature(layers)
        joint_embed = self.__flattenSparse(getCrossSimi(layers, sent, self.vocab_))
        
        return np.hstack([txt_embed, img_embed, joint_embed])        
    
    def __getitem__(self, ind):
        img_name = '%s/%i.svg' % (self.img_dir, ind+1)
        txt_name = '%s/%i.txt' % (self.txt_dir, ind+1)
        
        # triplets
        triplets = []
        # true match
        triplets.append(self.__getEmbed(txt_name=txt_name,
                                        img_name=img_name))
        # fake image
        triplets.append(self.__getEmbed(txt_name=txt_name,
                                        fake_img=True))
        # mismatched text
        triplets.append(self.__getEmbed(img_name=img_name,
                                        txt_name=txt_name,
                                        ran_txt=True))
        # mismatched image
        triplets.append(self.__getEmbed(img_name=img_name,
                                        txt_name=txt_name,
                                        ran_img=True))
        
        xs = np.vstack(triplets)
        
        # ys
        ys = np.array([1,0,0,0]).reshape(-1,1)
        
        return sparse.csr_matrix(np.hstack([xs, ys]))

    
    def __len__(self):
        return len(glob.glob(self.img_dir+'/*.svg'))
    
    def __get_featureNames(self):
        self.features_ = []
        # text features
        self.vocab_, _ = zip(*sorted(self.vectorizer.vocabulary_.items(),
                                     key=lambda x:x[::-1]))
        self.features_.extend(list(self.vocab_))

        # image features
        from tools.image_process import getNestedKey
        from rules.category import surrouding_dict, person_dict
        self.features_.append('_NLayers_')
        self.features_.extend(['_Background_',
                               '_Surroundings_',
                               '_Person_',
                               '_Decoration_'])
        srd_keys = getNestedKey(surrouding_dict)
        prs_keys = getNestedKey(person_dict)
        self.categ_ = srd_keys + prs_keys
        self.features_.extend(['_S_%s_' % k for k in srd_keys])
        self.features_.extend(['_P_%s_' % k for k in prs_keys])

        # joint features
        self.features_.extend(['_S_%s_%s_' % (k, t) for k in srd_keys for t in self.vocab_])
        self.features_.extend(['_P_%s_%s_' % (k, t) for k in prs_keys for t in self.vocab_])

# %%
layers, sent = dataset.getOneLayerSent(txt_name='text/1.txt',
                                       img_name='images/6.svg')
print(layers)
from tools.image_process import getNestedKeyWithCode, getNestedKey
from rules.category import surrouding_dict, person_dict
print(getNestedKeyWithCode(surrouding_dict, [1,1,2]))
print(getNestedKeyWithCode(person_dict, [1,1]))
print(sent)
# Out:
# ['A2112', 'A311']
# ['indoor', 'concrete', 'appliance']
# ['interact', 'office']
# ['man.n.01', 'look.v.01', 'chart.n.01', 'back.n.01']

# %%
from nltk.corpus import wordnet as wn
for syn in wn.synsets('building'):
    print(syn.name(),':', syn.definition())
# Out:
# street.n.01 : a thoroughfare (usually including sidewalks) that is lined with buildings
# street.n.02 : the part of a thoroughfare between the sidewalks; the part of the thoroughfare on which vehicles travel
# street.n.03 : the streets of a city viewed as a depressed environment in which there is poverty and crime and prostitution and dereliction
# street.n.04 : a situation offering opportunities
# street.n.05 : people living or working on the same street

# %%
from tools.image_process import getCrossSimi
print(getCrossSimi(layers, sent, dataset.vocab_))
# Out:
#   (1, 4)	1.3350010667323402
#   (1, 14)	1.2396908869280152
#   (1, 45)	1.8718021769015913
#   (1, 50)	1.4403615823901665
#   (3, 4)	1.2396908869280152
#   (3, 14)	1.1526795099383855
#   (3, 50)	1.3350010667323402
#   (17, 45)	1.8718021769015913
#   (18, 4)	1.3350010667323402
#   (18, 14)	1.6916760106710724
#   (18, 50)	1.3350010667323402

# %%
# sanity check
print(dataset.categ_[1])
print(dataset.categ_[3])
print(dataset.categ_[17])
print(dataset.categ_[18])
print('--')
print(dataset.vocab_[4])
print(dataset.vocab_[14])
print(dataset.vocab_[45])
print(dataset.vocab_[50])
# The problem is, bigrams will never contribute to the cross similarity
# Out:
# concrete
# appliance
# interact
# office
# --
# back.n.01
# chart.n.01
# look.v.01
# man.n.01

# %%
len(dataset.vocab_)
# Out:
# 103

# %%
from sklearn.linear_model import LogisticRegression
dataset = Dataset()
print('# features: ', len(dataset.features_))
data = sparse.vstack([dataset[i] for i in range(len(dataset))])
X, y = data[:,:-1], data[:,-1]
y = y.toarray().flatten()
print('data shape', data.shape)
# Out:
# /Users/dongjustin/Documents/Text2Scene/Text2Scene/tools/text_process.py:48: UserWarning: "sideways" does not belong to any synsets.
#   warnings.warn('"%s" does not belong to any synsets.' % lemma)
# /Users/dongjustin/Documents/Text2Scene/Text2Scene/tools/text_process.py:48: UserWarning: "grid" does not belong to any synsets.
#   warnings.warn('"%s" does not belong to any synsets.' % lemma)
# /Users/dongjustin/Documents/Text2Scene/Text2Scene/tools/text_process.py:48: UserWarning: "grid" does not belong to any synsets.
#   warnings.warn('"%s" does not belong to any synsets.' % lemma)
# # features:  3540
# /Users/dongjustin/Documents/Text2Scene/Text2Scene/tools/text_process.py:48: UserWarning: "sideways" does not belong to any synsets.
#   warnings.warn('"%s" does not belong to any synsets.' % lemma)
# data shape (80, 3541)

# %%
clf = LogisticRegression(# random_state=0,
                         solver='liblinear',
                         class_weight={1: 1, 0:0.5},
                         penalty='l1', #'l2' use l1 to learn sparsely
                         C=1.0,
                         max_iter=100)

clf.fit(X, y)
# Out:
# LogisticRegression(C=1.0, class_weight={0: 0.5, 1: 1}, dual=False,
#                    fit_intercept=True, intercept_scaling=1, l1_ratio=None,
#                    max_iter=100, multi_class='warn', n_jobs=None, penalty='l1',
#                    random_state=None, solver='liblinear', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
import matplotlib.pyplot as plt

# %%
print('Accuracy: ', clf.score(X,y))
# print(clf.predict(X))
# print(clf.predict_proba(X)[:,1])
# print(y)
plt.hist(clf.predict_proba(X)[:,1])
plt.show()
# Out:
# Accuracy:  0.875

# %%
d = dict(zip(dataset.features_, clf.coef_.tolist()[0]))
sorted(d.items(), key=lambda x: abs(x[1]))[::-1]
# Out:
# [('_P_stand_stand.v.01_', 1.3497430920118971),
#  ('_P_show_show.v.01_', 0.8631075022239184),
#  ('stand.v.01', -0.7215977471603678),
#  ('_P_sit_sit.v.01_', 0.4866960156557196),
#  ('_P_stand_be.v.01_', -0.395648618053632),
#  ('_P_lean_lean.v.01_', 0.3899665101799786),
#  ('_P_interact_be.v.01_', 0.3456291790908246),
#  ('_S_nature_rock.n.01_', 0.3103577901738671),
#  ('_NLayers_', -0.2465350792698374),
#  ('_S_art_play.n.01_', 0.21928998803359095),
#  ('_P_back_back.n.01_', 0.1756528924298931),
#  ('_P_sport_web.n.01_', 0.16636919132613448),
#  ('_S_concrete_airport.n.01_', 0.16065364194989162),
#  ('_S_appliance_computer.n.01_', 0.15475887768876714),
#  ('be.v.01', -0.1505430698349989),
#  ('_P_sport_man.n.01_', 0.11774384239466941),
#  ('chart.n.01', -0.10529692388118062),
#  ('show.v.01 form.n.01', -0.07331237330004037),
#  ('_S_chart_chart.n.01_', 0.06893228505755179),
#  ('show.v.01 chart.n.01', -0.06810274160755829),
#  ('_P_person_woman.n.01_', 0.05123485236722636),
#  ('_S_abstract_be.v.01_', -0.035516291760928485),
#  ('man.n.01 show.v.01', -0.032063487365714724),
#  ('male_child.n.01 be.v.01', -0.026764461830311618),
#  ('_S_wall_window.n.01_', 0.010512141604930091),
#  ('_S_wall_airport.n.01_', 0.005248048950052403),
#  ('_S_abstract_chart.n.01_', 0.004304595869182033),
#  ('form.n.01', -0.0006552536748270241),
#  ('male_child.n.01', -8.288830679431475e-05),
#  ('_P_gesture_wood.n.01_', 0.0),
#  ('_P_gesture_woman.n.01 stand.v.01_', 0.0),
#  ('_P_gesture_woman.n.01 play.n.01_', 0.0),
#  ('_P_gesture_woman.n.01 be.v.01_', 0.0),
#  ('_P_gesture_woman.n.01_', 0.0),
#  ('_P_gesture_window.n.01_', 0.0),
#  ('_P_gesture_web.n.01 icon.n.01_', 0.0),
#  ('_P_gesture_web.n.01_', 0.0),
#  ('_P_gesture_walk.v.01 past.n.01_', 0.0),
#  ('_P_gesture_walk.v.01_', 0.0),
#  ('_P_gesture_three.n.01 hallmark.n.01_', 0.0),
#  ('_P_gesture_three.n.01_', 0.0),
#  ('_P_gesture_telephone.n.01 chart.n.01_', 0.0),
#  ('_P_gesture_telephone.n.01_', 0.0),
#  ('_P_gesture_sword.n.01 rock.n.01_', 0.0),
#  ('_P_gesture_sword.n.01_', 0.0),
#  ('_P_gesture_stand.v.01 front.n.01_', 0.0),
#  ('_P_gesture_stand.v.01 following.s.02_', 0.0),
#  ('_P_gesture_stand.v.01 edge.n.01_', 0.0),
#  ('_P_gesture_stand.v.01_', 0.0),
#  ('_P_gesture_sit.v.01 wood.n.01_', 0.0),
#  ('_P_gesture_sit.v.01_', 0.0),
#  ('_P_gesture_show.v.01 muscle.n.01_', 0.0),
#  ('_P_gesture_show.v.01 love.v.01_', 0.0),
#  ('_P_gesture_show.v.01 form.n.01_', 0.0),
#  ('_P_gesture_show.v.01 chart.n.01_', 0.0),
#  ('_P_gesture_show.v.01_', 0.0),
#  ('_P_gesture_set.n.01 chart.n.01_', 0.0),
#  ('_P_gesture_set.n.01_', 0.0),
#  ('_P_gesture_rock.n.01_', 0.0),
#  ('_P_gesture_pull.v.01 sword.n.01_', 0.0),
#  ('_P_gesture_pull.v.01_', 0.0),
#  ('_P_gesture_poster.n.01 planet.n.01_', 0.0),
#  ('_P_gesture_poster.n.01_', 0.0),
#  ('_P_gesture_play.n.01 circle.n.01_', 0.0),
#  ('_P_gesture_play.n.01_', 0.0),
#  ('_P_gesture_planet.n.01_', 0.0),
#  ('_P_gesture_person.n.01_', 0.0),
#  ('_P_gesture_past.n.01 web.n.01_', 0.0),
#  ('_P_gesture_past.n.01_', 0.0),
#  ('_P_gesture_muscle.n.01_', 0.0),
#  ('_P_gesture_mobile.n.01 telephone.n.01_', 0.0),
#  ('_P_gesture_mobile.n.01_', 0.0),
#  ('_P_gesture_man.n.01 woman.n.01_', 0.0),
#  ('_P_gesture_man.n.01 walk.v.01_', 0.0),
#  ('_P_gesture_man.n.01 stand.v.01_', 0.0),
#  ('_P_gesture_man.n.01 show.v.01_', 0.0),
#  ('_P_gesture_man.n.01 pull.v.01_', 0.0),
#  ('_P_gesture_man.n.01 look.v.01_', 0.0),
#  ('_P_gesture_man.n.01 lean.v.01_', 0.0),
#  ('_P_gesture_man.n.01 drink.v.01_', 0.0),
#  ('_P_gesture_man.n.01 be.v.01_', 0.0),
#  ('_P_gesture_man.n.01_', 0.0),
#  ('_P_gesture_male_child.n.01 be.v.01_', 0.0),
#  ('_P_gesture_male_child.n.01_', 0.0),
#  ('_P_gesture_love.v.01_', 0.0),
#  ('_P_gesture_look.v.01 chart.n.01_', 0.0),
#  ('_P_gesture_look.v.01_', 0.0),
#  ('_P_gesture_lean.v.01 set.n.01_', 0.0),
#  ('_P_gesture_lean.v.01 car.n.01_', 0.0),
#  ('_P_gesture_lean.v.01_', 0.0),
#  ('_P_gesture_interact.v.01_', 0.0),
#  ('_P_gesture_icon.n.01_', 0.0),
#  ('_P_gesture_hallmark.n.01 about.r.03_', 0.0),
#  ('_P_gesture_hallmark.n.01_', 0.0),
#  ('_P_gesture_girl.n.01 be.v.01_', 0.0),
#  ('_P_gesture_girl.n.01_', 0.0),
#  ('_P_gesture_front.n.01 chart.n.01_', 0.0),
#  ('_P_gesture_front.n.01_', 0.0),
#  ('_P_gesture_form.n.01_', 0.0),
#  ('_P_gesture_following.s.02 poster.n.01_', 0.0),
#  ('_P_gesture_following.s.02 icon.n.01_', 0.0),
#  ('_P_gesture_following.s.02_', 0.0),
#  ('_P_gesture_edge.n.01 city.n.01_', 0.0),
#  ('_P_gesture_edge.n.01_', 0.0),
#  ('_P_gesture_drink.v.01 coffee.n.01_', 0.0),
#  ('_P_gesture_drink.v.01_', 0.0),
#  ('_P_gesture_computer.n.01_', 0.0),
#  ('_P_gesture_compass.n.01_', 0.0),
#  ('_P_gesture_coffee.n.01 airport.n.01_', 0.0),
#  ('_P_gesture_coffee.n.01_', 0.0),
#  ('_P_gesture_clean.v.01 computer.n.01_', 0.0),
#  ('_P_gesture_clean.v.01_', 0.0),
#  ('_P_gesture_city.n.01_', 0.0),
#  ('_P_gesture_circle.n.01 compass.n.01_', 0.0),
#  ('_P_gesture_circle.n.01_', 0.0),
#  ('_P_gesture_chart.n.01 show.v.01_', 0.0),
#  ('_P_gesture_chart.n.01 back.n.01_', 0.0),
#  ('_P_gesture_chart.n.01_', 0.0),
#  ('_P_gesture_car.n.01_', 0.0),
#  ('_P_gesture_be.v.01 three.n.01_', 0.0),
#  ('_P_gesture_be.v.01 stand.v.01_', 0.0),
#  ('_P_gesture_be.v.01 sit.v.01_', 0.0),
#  ('_P_gesture_be.v.01 show.v.01_', 0.0),
#  ('_P_gesture_be.v.01 lean.v.01_', 0.0),
#  ('_P_gesture_be.v.01 interact.v.01_', 0.0),
#  ('_P_gesture_be.v.01 clean.v.01_', 0.0),
#  ('_P_gesture_be.v.01_', 0.0),
#  ('_P_gesture_back.n.01_', 0.0),
#  ('_P_gesture_airport.n.01 window.n.01_', 0.0),
#  ('_P_gesture_airport.n.01_', 0.0),
#  ('_P_gesture_about.r.03 person.n.01_', 0.0),
#  ('_P_gesture_about.r.03_', 0.0),
#  ('_P_show_wood.n.01_', 0.0),
#  ('_P_show_woman.n.01 stand.v.01_', 0.0),
#  ('_P_show_woman.n.01 play.n.01_', 0.0),
#  ('_P_show_woman.n.01 be.v.01_', 0.0),
#  ('_P_show_woman.n.01_', 0.0),
#  ('_P_show_window.n.01_', 0.0),
#  ('_P_show_web.n.01 icon.n.01_', 0.0),
#  ('_P_show_web.n.01_', 0.0),
#  ('_P_show_walk.v.01 past.n.01_', 0.0),
#  ('_P_show_walk.v.01_', 0.0),
#  ('_P_show_three.n.01 hallmark.n.01_', 0.0),
#  ('_P_show_three.n.01_', 0.0),
#  ('_P_show_telephone.n.01 chart.n.01_', 0.0),
#  ('_P_show_telephone.n.01_', 0.0),
#  ('_P_show_sword.n.01 rock.n.01_', 0.0),
#  ('_P_show_sword.n.01_', 0.0),
#  ('_P_show_stand.v.01 front.n.01_', 0.0),
#  ('_P_show_stand.v.01 following.s.02_', 0.0),
#  ('_P_show_stand.v.01 edge.n.01_', 0.0),
#  ('_P_show_stand.v.01_', 0.0),
#  ('_P_show_sit.v.01 wood.n.01_', 0.0),
#  ('_P_show_sit.v.01_', 0.0),
#  ('_P_show_show.v.01 muscle.n.01_', 0.0),
#  ('_P_show_show.v.01 love.v.01_', 0.0),
#  ('_P_show_show.v.01 form.n.01_', 0.0),
#  ('_P_show_show.v.01 chart.n.01_', 0.0),
#  ('_P_show_set.n.01 chart.n.01_', 0.0),
#  ('_P_show_set.n.01_', 0.0),
#  ('_P_show_rock.n.01_', 0.0),
#  ('_P_show_pull.v.01 sword.n.01_', 0.0),
#  ('_P_show_pull.v.01_', 0.0),
#  ('_P_show_poster.n.01 planet.n.01_', 0.0),
#  ('_P_show_poster.n.01_', 0.0),
#  ('_P_show_play.n.01 circle.n.01_', 0.0),
#  ('_P_show_play.n.01_', 0.0),
#  ('_P_show_planet.n.01_', 0.0),
#  ('_P_show_person.n.01_', 0.0),
#  ('_P_show_past.n.01 web.n.01_', 0.0),
#  ('_P_show_past.n.01_', 0.0),
#  ('_P_show_muscle.n.01_', 0.0),
#  ('_P_show_mobile.n.01 telephone.n.01_', 0.0),
#  ('_P_show_mobile.n.01_', 0.0),
#  ('_P_show_man.n.01 woman.n.01_', 0.0),
#  ('_P_show_man.n.01 walk.v.01_', 0.0),
#  ('_P_show_man.n.01 stand.v.01_', 0.0),
#  ('_P_show_man.n.01 show.v.01_', 0.0),
#  ('_P_show_man.n.01 pull.v.01_', 0.0),
#  ('_P_show_man.n.01 look.v.01_', 0.0),
#  ('_P_show_man.n.01 lean.v.01_', 0.0),
#  ('_P_show_man.n.01 drink.v.01_', 0.0),
#  ('_P_show_man.n.01 be.v.01_', 0.0),
#  ('_P_show_man.n.01_', 0.0),
#  ('_P_show_male_child.n.01 be.v.01_', 0.0),
#  ('_P_show_male_child.n.01_', 0.0),
#  ('_P_show_love.v.01_', 0.0),
#  ('_P_show_look.v.01 chart.n.01_', 0.0),
#  ('_P_show_look.v.01_', 0.0),
#  ('_P_show_lean.v.01 set.n.01_', 0.0),
#  ('_P_show_lean.v.01 car.n.01_', 0.0),
#  ('_P_show_lean.v.01_', 0.0),
#  ('_P_show_interact.v.01_', 0.0),
#  ('_P_show_icon.n.01_', 0.0),
#  ('_P_show_hallmark.n.01 about.r.03_', 0.0),
#  ('_P_show_hallmark.n.01_', 0.0),
#  ('_P_show_girl.n.01 be.v.01_', 0.0),
#  ('_P_show_girl.n.01_', 0.0),
#  ('_P_show_front.n.01 chart.n.01_', 0.0),
#  ('_P_show_front.n.01_', 0.0),
#  ('_P_show_form.n.01_', 0.0),
#  ('_P_show_following.s.02 poster.n.01_', 0.0),
#  ('_P_show_following.s.02 icon.n.01_', 0.0),
#  ('_P_show_following.s.02_', 0.0),
#  ('_P_show_edge.n.01 city.n.01_', 0.0),
#  ('_P_show_edge.n.01_', 0.0),
#  ('_P_show_drink.v.01 coffee.n.01_', 0.0),
#  ('_P_show_drink.v.01_', 0.0),
#  ('_P_show_computer.n.01_', 0.0),
#  ('_P_show_compass.n.01_', 0.0),
#  ('_P_show_coffee.n.01 airport.n.01_', 0.0),
#  ('_P_show_coffee.n.01_', 0.0),
#  ('_P_show_clean.v.01 computer.n.01_', 0.0),
#  ('_P_show_clean.v.01_', 0.0),
#  ('_P_show_city.n.01_', 0.0),
#  ('_P_show_circle.n.01 compass.n.01_', 0.0),
#  ('_P_show_circle.n.01_', 0.0),
#  ('_P_show_chart.n.01 show.v.01_', 0.0),
#  ('_P_show_chart.n.01 back.n.01_', 0.0),
#  ('_P_show_chart.n.01_', 0.0),
#  ('_P_show_car.n.01_', 0.0),
#  ('_P_show_be.v.01 three.n.01_', 0.0),
#  ('_P_show_be.v.01 stand.v.01_', 0.0),
#  ('_P_show_be.v.01 sit.v.01_', 0.0),
#  ('_P_show_be.v.01 show.v.01_', 0.0),
#  ('_P_show_be.v.01 lean.v.01_', 0.0),
#  ('_P_show_be.v.01 interact.v.01_', 0.0),
#  ('_P_show_be.v.01 clean.v.01_', 0.0),
#  ('_P_show_be.v.01_', 0.0),
#  ('_P_show_back.n.01_', 0.0),
#  ('_P_show_airport.n.01 window.n.01_', 0.0),
#  ('_P_show_airport.n.01_', 0.0),
#  ('_P_show_about.r.03 person.n.01_', 0.0),
#  ('_P_show_about.r.03_', 0.0),
#  ('_P_sport_wood.n.01_', 0.0),
#  ('_P_sport_woman.n.01 stand.v.01_', 0.0),
#  ('_P_sport_woman.n.01 play.n.01_', 0.0),
#  ('_P_sport_woman.n.01 be.v.01_', 0.0),
#  ('_P_sport_woman.n.01_', 0.0),
#  ('_P_sport_window.n.01_', 0.0),
#  ('_P_sport_web.n.01 icon.n.01_', 0.0),
#  ('_P_sport_walk.v.01 past.n.01_', 0.0),
#  ('_P_sport_walk.v.01_', 0.0),
#  ('_P_sport_three.n.01 hallmark.n.01_', 0.0),
#  ('_P_sport_three.n.01_', 0.0),
#  ('_P_sport_telephone.n.01 chart.n.01_', 0.0),
#  ('_P_sport_telephone.n.01_', 0.0),
#  ('_P_sport_sword.n.01 rock.n.01_', 0.0),
#  ('_P_sport_sword.n.01_', 0.0),
#  ('_P_sport_stand.v.01 front.n.01_', 0.0),
#  ('_P_sport_stand.v.01 following.s.02_', 0.0),
#  ('_P_sport_stand.v.01 edge.n.01_', 0.0),
#  ('_P_sport_stand.v.01_', 0.0),
#  ('_P_sport_sit.v.01 wood.n.01_', 0.0),
#  ('_P_sport_sit.v.01_', 0.0),
#  ('_P_sport_show.v.01 muscle.n.01_', 0.0),
#  ('_P_sport_show.v.01 love.v.01_', 0.0),
#  ('_P_sport_show.v.01 form.n.01_', 0.0),
#  ('_P_sport_show.v.01 chart.n.01_', 0.0),
#  ('_P_sport_show.v.01_', 0.0),
#  ('_P_sport_set.n.01 chart.n.01_', 0.0),
#  ('_P_sport_set.n.01_', 0.0),
#  ('_P_sport_rock.n.01_', 0.0),
#  ('_P_sport_pull.v.01 sword.n.01_', 0.0),
#  ('_P_sport_pull.v.01_', 0.0),
#  ('_P_sport_poster.n.01 planet.n.01_', 0.0),
#  ('_P_sport_poster.n.01_', 0.0),
#  ('_P_sport_play.n.01 circle.n.01_', 0.0),
#  ('_P_sport_play.n.01_', 0.0),
#  ('_P_sport_planet.n.01_', 0.0),
#  ('_P_sport_person.n.01_', 0.0),
#  ('_P_sport_past.n.01 web.n.01_', 0.0),
#  ('_P_sport_past.n.01_', 0.0),
#  ('_P_sport_muscle.n.01_', 0.0),
#  ('_P_sport_mobile.n.01 telephone.n.01_', 0.0),
#  ('_P_sport_mobile.n.01_', 0.0),
#  ('_P_sport_man.n.01 woman.n.01_', 0.0),
#  ('_P_sport_man.n.01 walk.v.01_', 0.0),
#  ('_P_sport_man.n.01 stand.v.01_', 0.0),
#  ('_P_sport_man.n.01 show.v.01_', 0.0),
#  ('_P_sport_man.n.01 pull.v.01_', 0.0),
#  ('_P_sport_man.n.01 look.v.01_', 0.0),
#  ('_P_sport_man.n.01 lean.v.01_', 0.0),
#  ('_P_sport_man.n.01 drink.v.01_', 0.0),
#  ('_P_sport_man.n.01 be.v.01_', 0.0),
#  ('_P_sport_male_child.n.01 be.v.01_', 0.0),
#  ('_P_sport_male_child.n.01_', 0.0),
#  ('_P_sport_love.v.01_', 0.0),
#  ('_P_sport_look.v.01 chart.n.01_', 0.0),
#  ('_P_sport_look.v.01_', 0.0),
#  ('_P_sport_lean.v.01 set.n.01_', 0.0),
#  ('_P_sport_lean.v.01 car.n.01_', 0.0),
#  ('_P_sport_lean.v.01_', 0.0),
#  ('_P_sport_interact.v.01_', 0.0),
#  ('_P_sport_icon.n.01_', 0.0),
#  ('_P_sport_hallmark.n.01 about.r.03_', 0.0),
#  ('_P_sport_hallmark.n.01_', 0.0),
#  ('_P_sport_girl.n.01 be.v.01_', 0.0),
#  ('_P_sport_girl.n.01_', 0.0),
#  ('_P_sport_front.n.01 chart.n.01_', 0.0),
#  ('_P_sport_front.n.01_', 0.0),
#  ('_P_sport_form.n.01_', 0.0),
#  ('_P_sport_following.s.02 poster.n.01_', 0.0),
#  ('_P_sport_following.s.02 icon.n.01_', 0.0),
#  ('_P_sport_following.s.02_', 0.0),
#  ('_P_sport_edge.n.01 city.n.01_', 0.0),
#  ('_P_sport_edge.n.01_', 0.0),
#  ('_P_sport_drink.v.01 coffee.n.01_', 0.0),
#  ('_P_sport_drink.v.01_', 0.0),
#  ('_P_sport_computer.n.01_', 0.0),
#  ('_P_sport_compass.n.01_', 0.0),
#  ('_P_sport_coffee.n.01 airport.n.01_', 0.0),
#  ('_P_sport_coffee.n.01_', 0.0),
#  ('_P_sport_clean.v.01 computer.n.01_', 0.0),
#  ('_P_sport_clean.v.01_', 0.0),
#  ('_P_sport_city.n.01_', 0.0),
#  ('_P_sport_circle.n.01 compass.n.01_', 0.0),
#  ('_P_sport_circle.n.01_', 0.0),
#  ('_P_sport_chart.n.01 show.v.01_', 0.0),
#  ('_P_sport_chart.n.01 back.n.01_', 0.0),
#  ('_P_sport_chart.n.01_', 0.0),
#  ('_P_sport_car.n.01_', 0.0),
#  ('_P_sport_be.v.01 three.n.01_', 0.0),
#  ('_P_sport_be.v.01 stand.v.01_', 0.0),
#  ('_P_sport_be.v.01 sit.v.01_', 0.0),
#  ('_P_sport_be.v.01 show.v.01_', 0.0),
#  ('_P_sport_be.v.01 lean.v.01_', 0.0),
#  ('_P_sport_be.v.01 interact.v.01_', 0.0),
#  ('_P_sport_be.v.01 clean.v.01_', 0.0),
#  ('_P_sport_be.v.01_', 0.0),
#  ('_P_sport_back.n.01_', 0.0),
#  ('_P_sport_airport.n.01 window.n.01_', 0.0),
#  ('_P_sport_airport.n.01_', 0.0),
#  ('_P_sport_about.r.03 person.n.01_', 0.0),
#  ('_P_sport_about.r.03_', 0.0),
#  ('_P_sit_wood.n.01_', 0.0),
#  ('_P_sit_woman.n.01 stand.v.01_', 0.0),
#  ('_P_sit_woman.n.01 play.n.01_', 0.0),
#  ('_P_sit_woman.n.01 be.v.01_', 0.0),
#  ('_P_sit_woman.n.01_', 0.0),
#  ('_P_sit_window.n.01_', 0.0),
#  ('_P_sit_web.n.01 icon.n.01_', 0.0),
#  ('_P_sit_web.n.01_', 0.0),
#  ('_P_sit_walk.v.01 past.n.01_', 0.0),
#  ('_P_sit_walk.v.01_', 0.0),
#  ('_P_sit_three.n.01 hallmark.n.01_', 0.0),
#  ('_P_sit_three.n.01_', 0.0),
#  ('_P_sit_telephone.n.01 chart.n.01_', 0.0),
#  ('_P_sit_telephone.n.01_', 0.0),
#  ('_P_sit_sword.n.01 rock.n.01_', 0.0),
#  ('_P_sit_sword.n.01_', 0.0),
#  ('_P_sit_stand.v.01 front.n.01_', 0.0),
#  ('_P_sit_stand.v.01 following.s.02_', 0.0),
#  ('_P_sit_stand.v.01 edge.n.01_', 0.0),
#  ('_P_sit_stand.v.01_', 0.0),
#  ('_P_sit_sit.v.01 wood.n.01_', 0.0),
#  ('_P_sit_show.v.01 muscle.n.01_', 0.0),
#  ('_P_sit_show.v.01 love.v.01_', 0.0),
#  ('_P_sit_show.v.01 form.n.01_', 0.0),
#  ('_P_sit_show.v.01 chart.n.01_', 0.0),
#  ('_P_sit_show.v.01_', 0.0),
#  ('_P_sit_set.n.01 chart.n.01_', 0.0),
#  ('_P_sit_set.n.01_', 0.0),
#  ('_P_sit_rock.n.01_', 0.0),
#  ('_P_sit_pull.v.01 sword.n.01_', 0.0),
#  ('_P_sit_pull.v.01_', 0.0),
#  ('_P_sit_poster.n.01 planet.n.01_', 0.0),
#  ('_P_sit_poster.n.01_', 0.0),
#  ('_P_sit_play.n.01 circle.n.01_', 0.0),
#  ('_P_sit_play.n.01_', 0.0),
#  ('_P_sit_planet.n.01_', 0.0),
#  ('_P_sit_person.n.01_', 0.0),
#  ('_P_sit_past.n.01 web.n.01_', 0.0),
#  ('_P_sit_past.n.01_', 0.0),
#  ('_P_sit_muscle.n.01_', 0.0),
#  ('_P_sit_mobile.n.01 telephone.n.01_', 0.0),
#  ('_P_sit_mobile.n.01_', 0.0),
#  ('_P_sit_man.n.01 woman.n.01_', 0.0),
#  ('_P_sit_man.n.01 walk.v.01_', 0.0),
#  ('_P_sit_man.n.01 stand.v.01_', 0.0),
#  ('_P_sit_man.n.01 show.v.01_', 0.0),
#  ('_P_sit_man.n.01 pull.v.01_', 0.0),
#  ('_P_sit_man.n.01 look.v.01_', 0.0),
#  ('_P_sit_man.n.01 lean.v.01_', 0.0),
#  ('_P_sit_man.n.01 drink.v.01_', 0.0),
#  ('_P_sit_man.n.01 be.v.01_', 0.0),
#  ('_P_sit_man.n.01_', 0.0),
#  ('_P_sit_male_child.n.01 be.v.01_', 0.0),
#  ('_P_sit_male_child.n.01_', 0.0),
#  ('_P_sit_love.v.01_', 0.0),
#  ('_P_sit_look.v.01 chart.n.01_', 0.0),
#  ('_P_sit_look.v.01_', 0.0),
#  ('_P_sit_lean.v.01 set.n.01_', 0.0),
#  ('_P_sit_lean.v.01 car.n.01_', 0.0),
#  ('_P_sit_lean.v.01_', 0.0),
#  ('_P_sit_interact.v.01_', 0.0),
#  ('_P_sit_icon.n.01_', 0.0),
#  ('_P_sit_hallmark.n.01 about.r.03_', 0.0),
#  ('_P_sit_hallmark.n.01_', 0.0),
#  ('_P_sit_girl.n.01 be.v.01_', 0.0),
#  ('_P_sit_girl.n.01_', 0.0),
#  ('_P_sit_front.n.01 chart.n.01_', 0.0),
#  ('_P_sit_front.n.01_', 0.0),
#  ('_P_sit_form.n.01_', 0.0),
#  ('_P_sit_following.s.02 poster.n.01_', 0.0),
#  ('_P_sit_following.s.02 icon.n.01_', 0.0),
#  ('_P_sit_following.s.02_', 0.0),
#  ('_P_sit_edge.n.01 city.n.01_', 0.0),
#  ('_P_sit_edge.n.01_', 0.0),
#  ('_P_sit_drink.v.01 coffee.n.01_', 0.0),
#  ('_P_sit_drink.v.01_', 0.0),
#  ('_P_sit_computer.n.01_', 0.0),
#  ('_P_sit_compass.n.01_', 0.0),
#  ('_P_sit_coffee.n.01 airport.n.01_', 0.0),
#  ('_P_sit_coffee.n.01_', 0.0),
#  ('_P_sit_clean.v.01 computer.n.01_', 0.0),
#  ('_P_sit_clean.v.01_', 0.0),
#  ('_P_sit_city.n.01_', 0.0),
#  ('_P_sit_circle.n.01 compass.n.01_', 0.0),
#  ('_P_sit_circle.n.01_', 0.0),
#  ('_P_sit_chart.n.01 show.v.01_', 0.0),
#  ('_P_sit_chart.n.01 back.n.01_', 0.0),
#  ('_P_sit_chart.n.01_', 0.0),
#  ('_P_sit_car.n.01_', 0.0),
#  ('_P_sit_be.v.01 three.n.01_', 0.0),
#  ('_P_sit_be.v.01 stand.v.01_', 0.0),
#  ('_P_sit_be.v.01 sit.v.01_', 0.0),
#  ('_P_sit_be.v.01 show.v.01_', 0.0),
#  ('_P_sit_be.v.01 lean.v.01_', 0.0),
#  ('_P_sit_be.v.01 interact.v.01_', 0.0),
#  ('_P_sit_be.v.01 clean.v.01_', 0.0),
#  ('_P_sit_be.v.01_', 0.0),
#  ('_P_sit_back.n.01_', 0.0),
#  ('_P_sit_airport.n.01 window.n.01_', 0.0),
#  ('_P_sit_airport.n.01_', 0.0),
#  ('_P_sit_about.r.03 person.n.01_', 0.0),
#  ('_P_sit_about.r.03_', 0.0),
#  ('_P_front_wood.n.01_', 0.0),
#  ('_P_front_woman.n.01 stand.v.01_', 0.0),
#  ('_P_front_woman.n.01 play.n.01_', 0.0),
#  ('_P_front_woman.n.01 be.v.01_', 0.0),
#  ('_P_front_woman.n.01_', 0.0),
#  ('_P_front_window.n.01_', 0.0),
#  ('_P_front_web.n.01 icon.n.01_', 0.0),
#  ('_P_front_web.n.01_', 0.0),
#  ('_P_front_walk.v.01 past.n.01_', 0.0),
#  ('_P_front_walk.v.01_', 0.0),
#  ('_P_front_three.n.01 hallmark.n.01_', 0.0),
#  ('_P_front_three.n.01_', 0.0),
#  ('_P_front_telephone.n.01 chart.n.01_', 0.0),
#  ('_P_front_telephone.n.01_', 0.0),
#  ('_P_front_sword.n.01 rock.n.01_', 0.0),
#  ('_P_front_sword.n.01_', 0.0),
#  ('_P_front_stand.v.01 front.n.01_', 0.0),
#  ('_P_front_stand.v.01 following.s.02_', 0.0),
#  ('_P_front_stand.v.01 edge.n.01_', 0.0),
#  ('_P_front_stand.v.01_', 0.0),
#  ('_P_front_sit.v.01 wood.n.01_', 0.0),
#  ('_P_front_sit.v.01_', 0.0),
#  ('_P_front_show.v.01 muscle.n.01_', 0.0),
#  ('_P_front_show.v.01 love.v.01_', 0.0),
#  ('_P_front_show.v.01 form.n.01_', 0.0),
#  ('_P_front_show.v.01 chart.n.01_', 0.0),
#  ('_P_front_show.v.01_', 0.0),
#  ('_P_front_set.n.01 chart.n.01_', 0.0),
#  ('_P_front_set.n.01_', 0.0),
#  ('_P_front_rock.n.01_', 0.0),
#  ('_P_front_pull.v.01 sword.n.01_', 0.0),
#  ('_P_front_pull.v.01_', 0.0),
#  ('_P_front_poster.n.01 planet.n.01_', 0.0),
#  ('_P_front_poster.n.01_', 0.0),
#  ('_P_front_play.n.01 circle.n.01_', 0.0),
#  ('_P_front_play.n.01_', 0.0),
#  ('_P_front_planet.n.01_', 0.0),
#  ('_P_front_person.n.01_', 0.0),
#  ('_P_front_past.n.01 web.n.01_', 0.0),
#  ('_P_front_past.n.01_', 0.0),
#  ('_P_front_muscle.n.01_', 0.0),
#  ('_P_front_mobile.n.01 telephone.n.01_', 0.0),
#  ('_P_front_mobile.n.01_', 0.0),
#  ('_P_front_man.n.01 woman.n.01_', 0.0),
#  ('_P_front_man.n.01 walk.v.01_', 0.0),
#  ('_P_front_man.n.01 stand.v.01_', 0.0),
#  ('_P_front_man.n.01 show.v.01_', 0.0),
#  ('_P_front_man.n.01 pull.v.01_', 0.0),
#  ('_P_front_man.n.01 look.v.01_', 0.0),
#  ('_P_front_man.n.01 lean.v.01_', 0.0),
#  ('_P_front_man.n.01 drink.v.01_', 0.0),
#  ('_P_front_man.n.01 be.v.01_', 0.0),
#  ('_P_front_man.n.01_', 0.0),
#  ('_P_front_male_child.n.01 be.v.01_', 0.0),
#  ('_P_front_male_child.n.01_', 0.0),
#  ('_P_front_love.v.01_', 0.0),
#  ('_P_front_look.v.01 chart.n.01_', 0.0),
#  ('_P_front_look.v.01_', 0.0),
#  ('_P_front_lean.v.01 set.n.01_', 0.0),
#  ('_P_front_lean.v.01 car.n.01_', 0.0),
#  ('_P_front_lean.v.01_', 0.0),
#  ('_P_front_interact.v.01_', 0.0),
#  ('_P_front_icon.n.01_', 0.0),
#  ('_P_front_hallmark.n.01 about.r.03_', 0.0),
#  ('_P_front_hallmark.n.01_', 0.0),
#  ('_P_front_girl.n.01 be.v.01_', 0.0),
#  ('_P_front_girl.n.01_', 0.0),
#  ('_P_front_front.n.01 chart.n.01_', 0.0),
#  ('_P_front_front.n.01_', 0.0),
#  ('_P_front_form.n.01_', 0.0),
#  ('_P_front_following.s.02 poster.n.01_', 0.0),
#  ('_P_front_following.s.02 icon.n.01_', 0.0),
#  ('_P_front_following.s.02_', 0.0),
#  ('_P_front_edge.n.01 city.n.01_', 0.0),
#  ('_P_front_edge.n.01_', 0.0),
#  ('_P_front_drink.v.01 coffee.n.01_', 0.0),
#  ('_P_front_drink.v.01_', 0.0),
#  ('_P_front_computer.n.01_', 0.0),
#  ('_P_front_compass.n.01_', 0.0),
#  ('_P_front_coffee.n.01 airport.n.01_', 0.0),
#  ('_P_front_coffee.n.01_', 0.0),
#  ('_P_front_clean.v.01 computer.n.01_', 0.0),
#  ('_P_front_clean.v.01_', 0.0),
#  ('_P_front_city.n.01_', 0.0),
#  ('_P_front_circle.n.01 compass.n.01_', 0.0),
#  ('_P_front_circle.n.01_', 0.0),
#  ('_P_front_chart.n.01 show.v.01_', 0.0),
#  ('_P_front_chart.n.01 back.n.01_', 0.0),
#  ('_P_front_chart.n.01_', 0.0),
#  ('_P_front_car.n.01_', 0.0),
#  ('_P_front_be.v.01 three.n.01_', 0.0),
#  ('_P_front_be.v.01 stand.v.01_', 0.0),
#  ('_P_front_be.v.01 sit.v.01_', 0.0),
#  ('_P_front_be.v.01 show.v.01_', 0.0),
#  ('_P_front_be.v.01 lean.v.01_', 0.0),
#  ('_P_front_be.v.01 interact.v.01_', 0.0),
#  ('_P_front_be.v.01 clean.v.01_', 0.0),
#  ('_P_front_be.v.01_', 0.0),
#  ('_P_front_back.n.01_', 0.0),
#  ('_P_front_airport.n.01 window.n.01_', 0.0),
#  ('_P_front_airport.n.01_', 0.0),
#  ('_P_front_about.r.03 person.n.01_', 0.0),
#  ('_P_front_about.r.03_', 0.0),
#  ('_P_back_wood.n.01_', 0.0),
#  ('_P_back_woman.n.01 stand.v.01_', 0.0),
#  ('_P_back_woman.n.01 play.n.01_', 0.0),
#  ('_P_back_woman.n.01 be.v.01_', 0.0),
#  ('_P_back_woman.n.01_', 0.0),
#  ('_P_back_window.n.01_', 0.0),
#  ('_P_back_web.n.01 icon.n.01_', 0.0),
#  ('_P_back_web.n.01_', 0.0),
#  ('_P_back_walk.v.01 past.n.01_', 0.0),
#  ('_P_back_walk.v.01_', 0.0),
#  ('_P_back_three.n.01 hallmark.n.01_', 0.0),
#  ('_P_back_three.n.01_', 0.0),
#  ('_P_back_telephone.n.01 chart.n.01_', 0.0),
#  ('_P_back_telephone.n.01_', 0.0),
#  ('_P_back_sword.n.01 rock.n.01_', 0.0),
#  ('_P_back_sword.n.01_', 0.0),
#  ('_P_back_stand.v.01 front.n.01_', 0.0),
#  ('_P_back_stand.v.01 following.s.02_', 0.0),
#  ('_P_back_stand.v.01 edge.n.01_', 0.0),
#  ('_P_back_stand.v.01_', 0.0),
#  ('_P_back_sit.v.01 wood.n.01_', 0.0),
#  ('_P_back_sit.v.01_', 0.0),
#  ('_P_back_show.v.01 muscle.n.01_', 0.0),
#  ('_P_back_show.v.01 love.v.01_', 0.0),
#  ('_P_back_show.v.01 form.n.01_', 0.0),
#  ('_P_back_show.v.01 chart.n.01_', 0.0),
#  ('_P_back_show.v.01_', 0.0),
#  ('_P_back_set.n.01 chart.n.01_', 0.0),
#  ('_P_back_set.n.01_', 0.0),
#  ('_P_back_rock.n.01_', 0.0),
#  ('_P_back_pull.v.01 sword.n.01_', 0.0),
#  ('_P_back_pull.v.01_', 0.0),
#  ('_P_back_poster.n.01 planet.n.01_', 0.0),
#  ('_P_back_poster.n.01_', 0.0),
#  ('_P_back_play.n.01 circle.n.01_', 0.0),
#  ('_P_back_play.n.01_', 0.0),
#  ('_P_back_planet.n.01_', 0.0),
#  ('_P_back_person.n.01_', 0.0),
#  ('_P_back_past.n.01 web.n.01_', 0.0),
#  ('_P_back_past.n.01_', 0.0),
#  ('_P_back_muscle.n.01_', 0.0),
#  ('_P_back_mobile.n.01 telephone.n.01_', 0.0),
#  ('_P_back_mobile.n.01_', 0.0),
#  ('_P_back_man.n.01 woman.n.01_', 0.0),
#  ('_P_back_man.n.01 walk.v.01_', 0.0),
#  ('_P_back_man.n.01 stand.v.01_', 0.0),
#  ('_P_back_man.n.01 show.v.01_', 0.0),
#  ('_P_back_man.n.01 pull.v.01_', 0.0),
#  ('_P_back_man.n.01 look.v.01_', 0.0),
#  ('_P_back_man.n.01 lean.v.01_', 0.0),
#  ('_P_back_man.n.01 drink.v.01_', 0.0),
#  ('_P_back_man.n.01 be.v.01_', 0.0),
#  ('_P_back_man.n.01_', 0.0),
#  ('_P_back_male_child.n.01 be.v.01_', 0.0),
#  ('_P_back_male_child.n.01_', 0.0),
#  ('_P_back_love.v.01_', 0.0),
#  ('_P_back_look.v.01 chart.n.01_', 0.0),
#  ('_P_back_look.v.01_', 0.0),
#  ('_P_back_lean.v.01 set.n.01_', 0.0),
#  ('_P_back_lean.v.01 car.n.01_', 0.0),
#  ('_P_back_lean.v.01_', 0.0),
#  ('_P_back_interact.v.01_', 0.0),
#  ('_P_back_icon.n.01_', 0.0),
#  ('_P_back_hallmark.n.01 about.r.03_', 0.0),
#  ('_P_back_hallmark.n.01_', 0.0),
#  ('_P_back_girl.n.01 be.v.01_', 0.0),
#  ('_P_back_girl.n.01_', 0.0),
#  ('_P_back_front.n.01 chart.n.01_', 0.0),
#  ('_P_back_front.n.01_', 0.0),
#  ('_P_back_form.n.01_', 0.0),
#  ('_P_back_following.s.02 poster.n.01_', 0.0),
#  ('_P_back_following.s.02 icon.n.01_', 0.0),
#  ('_P_back_following.s.02_', 0.0),
#  ('_P_back_edge.n.01 city.n.01_', 0.0),
#  ('_P_back_edge.n.01_', 0.0),
#  ('_P_back_drink.v.01 coffee.n.01_', 0.0),
#  ('_P_back_drink.v.01_', 0.0),
#  ('_P_back_computer.n.01_', 0.0),
#  ('_P_back_compass.n.01_', 0.0),
#  ('_P_back_coffee.n.01 airport.n.01_', 0.0),
#  ('_P_back_coffee.n.01_', 0.0),
#  ('_P_back_clean.v.01 computer.n.01_', 0.0),
#  ('_P_back_clean.v.01_', 0.0),
#  ('_P_back_city.n.01_', 0.0),
#  ('_P_back_circle.n.01 compass.n.01_', 0.0),
#  ('_P_back_circle.n.01_', 0.0),
#  ('_P_back_chart.n.01 show.v.01_', 0.0),
#  ('_P_back_chart.n.01 back.n.01_', 0.0),
#  ('_P_back_chart.n.01_', 0.0),
#  ('_P_back_car.n.01_', 0.0),
#  ('_P_back_be.v.01 three.n.01_', 0.0),
#  ('_P_back_be.v.01 stand.v.01_', 0.0),
#  ('_P_back_be.v.01 sit.v.01_', 0.0),
#  ('_P_back_be.v.01 show.v.01_', 0.0),
#  ('_P_back_be.v.01 lean.v.01_', 0.0),
#  ('_P_back_be.v.01 interact.v.01_', 0.0),
#  ('_P_back_be.v.01 clean.v.01_', 0.0),
#  ('_P_back_be.v.01_', 0.0),
#  ('_P_back_airport.n.01 window.n.01_', 0.0),
#  ('_P_back_airport.n.01_', 0.0),
#  ('_P_back_about.r.03 person.n.01_', 0.0),
#  ('_P_back_about.r.03_', 0.0),
#  ('_P_lean_wood.n.01_', 0.0),
#  ('_P_lean_woman.n.01 stand.v.01_', 0.0),
#  ('_P_lean_woman.n.01 play.n.01_', 0.0),
#  ('_P_lean_woman.n.01 be.v.01_', 0.0),
#  ('_P_lean_woman.n.01_', 0.0),
#  ('_P_lean_window.n.01_', 0.0),
#  ('_P_lean_web.n.01 icon.n.01_', 0.0),
#  ('_P_lean_web.n.01_', 0.0),
#  ('_P_lean_walk.v.01 past.n.01_', 0.0),
#  ('_P_lean_walk.v.01_', 0.0),
#  ('_P_lean_three.n.01 hallmark.n.01_', 0.0),
#  ('_P_lean_three.n.01_', 0.0),
#  ('_P_lean_telephone.n.01 chart.n.01_', 0.0),
#  ('_P_lean_telephone.n.01_', 0.0),
#  ('_P_lean_sword.n.01 rock.n.01_', 0.0),
#  ('_P_lean_sword.n.01_', 0.0),
#  ('_P_lean_stand.v.01 front.n.01_', 0.0),
#  ('_P_lean_stand.v.01 following.s.02_', 0.0),
#  ('_P_lean_stand.v.01 edge.n.01_', 0.0),
#  ('_P_lean_stand.v.01_', 0.0),
#  ('_P_lean_sit.v.01 wood.n.01_', 0.0),
#  ('_P_lean_sit.v.01_', 0.0),
#  ('_P_lean_show.v.01 muscle.n.01_', 0.0),
#  ('_P_lean_show.v.01 love.v.01_', 0.0),
#  ('_P_lean_show.v.01 form.n.01_', 0.0),
#  ('_P_lean_show.v.01 chart.n.01_', 0.0),
#  ('_P_lean_show.v.01_', 0.0),
#  ('_P_lean_set.n.01 chart.n.01_', 0.0),
#  ('_P_lean_set.n.01_', 0.0),
#  ('_P_lean_rock.n.01_', 0.0),
#  ('_P_lean_pull.v.01 sword.n.01_', 0.0),
#  ('_P_lean_pull.v.01_', 0.0),
#  ('_P_lean_poster.n.01 planet.n.01_', 0.0),
#  ('_P_lean_poster.n.01_', 0.0),
#  ('_P_lean_play.n.01 circle.n.01_', 0.0),
#  ('_P_lean_play.n.01_', 0.0),
#  ('_P_lean_planet.n.01_', 0.0),
#  ('_P_lean_person.n.01_', 0.0),
#  ('_P_lean_past.n.01 web.n.01_', 0.0),
#  ('_P_lean_past.n.01_', 0.0),
#  ('_P_lean_muscle.n.01_', 0.0),
#  ('_P_lean_mobile.n.01 telephone.n.01_', 0.0),
#  ('_P_lean_mobile.n.01_', 0.0),
#  ('_P_lean_man.n.01 woman.n.01_', 0.0),
#  ('_P_lean_man.n.01 walk.v.01_', 0.0),
#  ('_P_lean_man.n.01 stand.v.01_', 0.0),
#  ('_P_lean_man.n.01 show.v.01_', 0.0),
#  ('_P_lean_man.n.01 pull.v.01_', 0.0),
#  ('_P_lean_man.n.01 look.v.01_', 0.0),
#  ('_P_lean_man.n.01 lean.v.01_', 0.0),
#  ('_P_lean_man.n.01 drink.v.01_', 0.0),
#  ('_P_lean_man.n.01 be.v.01_', 0.0),
#  ('_P_lean_man.n.01_', 0.0),
#  ('_P_lean_male_child.n.01 be.v.01_', 0.0),
#  ('_P_lean_male_child.n.01_', 0.0),
#  ('_P_lean_love.v.01_', 0.0),
#  ('_P_lean_look.v.01 chart.n.01_', 0.0),
#  ('_P_lean_look.v.01_', 0.0),
#  ('_P_lean_lean.v.01 set.n.01_', 0.0),
#  ('_P_lean_lean.v.01 car.n.01_', 0.0),
#  ('_P_lean_interact.v.01_', 0.0),
#  ('_P_lean_icon.n.01_', 0.0),
#  ('_P_lean_hallmark.n.01 about.r.03_', 0.0),
#  ('_P_lean_hallmark.n.01_', 0.0),
#  ('_P_lean_girl.n.01 be.v.01_', 0.0),
#  ('_P_lean_girl.n.01_', 0.0),
#  ('_P_lean_front.n.01 chart.n.01_', 0.0),
#  ('_P_lean_front.n.01_', 0.0),
#  ('_P_lean_form.n.01_', 0.0),
#  ('_P_lean_following.s.02 poster.n.01_', 0.0),
#  ('_P_lean_following.s.02 icon.n.01_', 0.0),
#  ('_P_lean_following.s.02_', 0.0),
#  ('_P_lean_edge.n.01 city.n.01_', 0.0),
#  ('_P_lean_edge.n.01_', 0.0),
#  ('_P_lean_drink.v.01 coffee.n.01_', 0.0),
#  ('_P_lean_drink.v.01_', 0.0),
#  ('_P_lean_computer.n.01_', 0.0),
#  ('_P_lean_compass.n.01_', 0.0),
#  ('_P_lean_coffee.n.01 airport.n.01_', 0.0),
#  ('_P_lean_coffee.n.01_', 0.0),
#  ('_P_lean_clean.v.01 computer.n.01_', 0.0),
#  ('_P_lean_clean.v.01_', 0.0),
#  ('_P_lean_city.n.01_', 0.0),
#  ('_P_lean_circle.n.01 compass.n.01_', 0.0),
#  ('_P_lean_circle.n.01_', 0.0),
#  ('_P_lean_chart.n.01 show.v.01_', 0.0),
#  ('_P_lean_chart.n.01 back.n.01_', 0.0),
#  ('_P_lean_chart.n.01_', 0.0),
#  ('_P_lean_car.n.01_', 0.0),
#  ('_P_lean_be.v.01 three.n.01_', 0.0),
#  ('_P_lean_be.v.01 stand.v.01_', 0.0),
#  ('_P_lean_be.v.01 sit.v.01_', 0.0),
#  ('_P_lean_be.v.01 show.v.01_', 0.0),
#  ('_P_lean_be.v.01 lean.v.01_', 0.0),
#  ('_P_lean_be.v.01 interact.v.01_', 0.0),
#  ('_P_lean_be.v.01 clean.v.01_', 0.0),
#  ('_P_lean_be.v.01_', 0.0),
#  ('_P_lean_back.n.01_', 0.0),
#  ('_P_lean_airport.n.01 window.n.01_', 0.0),
#  ('_P_lean_airport.n.01_', 0.0),
#  ('_P_lean_about.r.03 person.n.01_', 0.0),
#  ('_P_lean_about.r.03_', 0.0),
#  ('_P_stand_wood.n.01_', 0.0),
#  ('_P_stand_woman.n.01 stand.v.01_', 0.0),
#  ('_P_stand_woman.n.01 play.n.01_', 0.0),
#  ('_P_stand_woman.n.01 be.v.01_', 0.0),
#  ('_P_stand_woman.n.01_', 0.0),
#  ('_P_stand_window.n.01_', 0.0),
#  ('_P_stand_web.n.01 icon.n.01_', 0.0),
#  ('_P_stand_web.n.01_', 0.0),
#  ('_P_stand_walk.v.01 past.n.01_', 0.0),
#  ('_P_stand_walk.v.01_', 0.0),
#  ('_P_stand_three.n.01 hallmark.n.01_', 0.0),
#  ('_P_stand_three.n.01_', 0.0),
#  ('_P_stand_telephone.n.01 chart.n.01_', 0.0),
#  ('_P_stand_telephone.n.01_', 0.0),
#  ('_P_stand_sword.n.01 rock.n.01_', 0.0),
#  ('_P_stand_sword.n.01_', 0.0),
#  ('_P_stand_stand.v.01 front.n.01_', 0.0),
#  ('_P_stand_stand.v.01 following.s.02_', 0.0),
#  ('_P_stand_stand.v.01 edge.n.01_', 0.0),
#  ('_P_stand_sit.v.01 wood.n.01_', 0.0),
#  ('_P_stand_sit.v.01_', 0.0),
#  ('_P_stand_show.v.01 muscle.n.01_', 0.0),
#  ('_P_stand_show.v.01 love.v.01_', 0.0),
#  ('_P_stand_show.v.01 form.n.01_', 0.0),
#  ('_P_stand_show.v.01 chart.n.01_', 0.0),
#  ('_P_stand_show.v.01_', 0.0),
#  ('_P_stand_set.n.01 chart.n.01_', 0.0),
#  ('_P_stand_set.n.01_', 0.0),
#  ('_P_stand_rock.n.01_', 0.0),
#  ('_P_stand_pull.v.01 sword.n.01_', 0.0),
#  ('_P_stand_pull.v.01_', 0.0),
#  ('_P_stand_poster.n.01 planet.n.01_', 0.0),
#  ('_P_stand_poster.n.01_', 0.0),
#  ('_P_stand_play.n.01 circle.n.01_', 0.0),
#  ('_P_stand_play.n.01_', 0.0),
#  ('_P_stand_planet.n.01_', 0.0),
#  ('_P_stand_person.n.01_', 0.0),
#  ('_P_stand_past.n.01 web.n.01_', 0.0),
#  ('_P_stand_past.n.01_', 0.0),
#  ('_P_stand_muscle.n.01_', 0.0),
#  ('_P_stand_mobile.n.01 telephone.n.01_', 0.0),
#  ('_P_stand_mobile.n.01_', 0.0),
#  ('_P_stand_man.n.01 woman.n.01_', 0.0),
#  ('_P_stand_man.n.01 walk.v.01_', 0.0),
#  ('_P_stand_man.n.01 stand.v.01_', 0.0),
#  ('_P_stand_man.n.01 show.v.01_', 0.0),
#  ('_P_stand_man.n.01 pull.v.01_', 0.0),
#  ('_P_stand_man.n.01 look.v.01_', 0.0),
#  ('_P_stand_man.n.01 lean.v.01_', 0.0),
#  ('_P_stand_man.n.01 drink.v.01_', 0.0),
#  ('_P_stand_man.n.01 be.v.01_', 0.0),
#  ('_P_stand_man.n.01_', 0.0),
#  ('_P_stand_male_child.n.01 be.v.01_', 0.0),
#  ('_P_stand_male_child.n.01_', 0.0),
#  ('_P_stand_love.v.01_', 0.0),
#  ('_P_stand_look.v.01 chart.n.01_', 0.0),
#  ('_P_stand_look.v.01_', 0.0),
#  ('_P_stand_lean.v.01 set.n.01_', 0.0),
#  ('_P_stand_lean.v.01 car.n.01_', 0.0),
#  ('_P_stand_lean.v.01_', 0.0),
#  ('_P_stand_interact.v.01_', 0.0),
#  ('_P_stand_icon.n.01_', 0.0),
#  ('_P_stand_hallmark.n.01 about.r.03_', 0.0),
#  ('_P_stand_hallmark.n.01_', 0.0),
#  ('_P_stand_girl.n.01 be.v.01_', 0.0),
#  ('_P_stand_girl.n.01_', 0.0),
#  ('_P_stand_front.n.01 chart.n.01_', 0.0),
#  ('_P_stand_front.n.01_', 0.0),
#  ('_P_stand_form.n.01_', 0.0),
#  ('_P_stand_following.s.02 poster.n.01_', 0.0),
#  ('_P_stand_following.s.02 icon.n.01_', 0.0),
#  ('_P_stand_following.s.02_', 0.0),
#  ('_P_stand_edge.n.01 city.n.01_', 0.0),
#  ('_P_stand_edge.n.01_', 0.0),
#  ('_P_stand_drink.v.01 coffee.n.01_', 0.0),
#  ('_P_stand_drink.v.01_', 0.0),
#  ('_P_stand_computer.n.01_', 0.0),
#  ('_P_stand_compass.n.01_', 0.0),
#  ('_P_stand_coffee.n.01 airport.n.01_', 0.0),
#  ('_P_stand_coffee.n.01_', 0.0),
#  ('_P_stand_clean.v.01 computer.n.01_', 0.0),
#  ('_P_stand_clean.v.01_', 0.0),
#  ('_P_stand_city.n.01_', 0.0),
#  ('_P_stand_circle.n.01 compass.n.01_', 0.0),
#  ('_P_stand_circle.n.01_', 0.0),
#  ('_P_stand_chart.n.01 show.v.01_', 0.0),
#  ('_P_stand_chart.n.01 back.n.01_', 0.0),
#  ('_P_stand_chart.n.01_', 0.0),
#  ('_P_stand_car.n.01_', 0.0),
#  ('_P_stand_be.v.01 three.n.01_', 0.0),
#  ('_P_stand_be.v.01 stand.v.01_', 0.0),
#  ('_P_stand_be.v.01 sit.v.01_', 0.0),
#  ('_P_stand_be.v.01 show.v.01_', 0.0),
#  ('_P_stand_be.v.01 lean.v.01_', 0.0),
#  ('_P_stand_be.v.01 interact.v.01_', 0.0),
#  ('_P_stand_be.v.01 clean.v.01_', 0.0),
#  ('_P_stand_back.n.01_', 0.0),
#  ('_P_stand_airport.n.01 window.n.01_', 0.0),
#  ('_P_stand_airport.n.01_', 0.0),
#  ('_P_stand_about.r.03 person.n.01_', 0.0),
#  ('_P_stand_about.r.03_', 0.0),
#  ('_P_person_wood.n.01_', 0.0),
#  ('_P_person_woman.n.01 stand.v.01_', 0.0),
#  ('_P_person_woman.n.01 play.n.01_', 0.0),
#  ('_P_person_woman.n.01 be.v.01_', 0.0),
#  ('_P_person_window.n.01_', 0.0),
#  ('_P_person_web.n.01 icon.n.01_', 0.0),
#  ('_P_person_web.n.01_', 0.0),
#  ('_P_person_walk.v.01 past.n.01_', 0.0),
#  ('_P_person_walk.v.01_', 0.0),
#  ('_P_person_three.n.01 hallmark.n.01_', 0.0),
#  ('_P_person_three.n.01_', 0.0),
#  ('_P_person_telephone.n.01 chart.n.01_', 0.0),
#  ('_P_person_telephone.n.01_', 0.0),
#  ('_P_person_sword.n.01 rock.n.01_', 0.0),
#  ('_P_person_sword.n.01_', 0.0),
#  ('_P_person_stand.v.01 front.n.01_', 0.0),
#  ('_P_person_stand.v.01 following.s.02_', 0.0),
#  ('_P_person_stand.v.01 edge.n.01_', 0.0),
#  ('_P_person_stand.v.01_', 0.0),
#  ('_P_person_sit.v.01 wood.n.01_', 0.0),
#  ('_P_person_sit.v.01_', 0.0),
#  ('_P_person_show.v.01 muscle.n.01_', 0.0),
#  ('_P_person_show.v.01 love.v.01_', 0.0),
#  ('_P_person_show.v.01 form.n.01_', 0.0),
#  ('_P_person_show.v.01 chart.n.01_', 0.0),
#  ('_P_person_show.v.01_', 0.0),
#  ('_P_person_set.n.01 chart.n.01_', 0.0),
#  ('_P_person_set.n.01_', 0.0),
#  ('_P_person_rock.n.01_', 0.0),
#  ('_P_person_pull.v.01 sword.n.01_', 0.0),
#  ('_P_person_pull.v.01_', 0.0),
#  ('_P_person_poster.n.01 planet.n.01_', 0.0),
#  ('_P_person_poster.n.01_', 0.0),
#  ('_P_person_play.n.01 circle.n.01_', 0.0),
#  ('_P_person_play.n.01_', 0.0),
#  ('_P_person_planet.n.01_', 0.0),
#  ('_P_person_person.n.01_', 0.0),
#  ('_P_person_past.n.01 web.n.01_', 0.0),
#  ('_P_person_past.n.01_', 0.0),
#  ('_P_person_muscle.n.01_', 0.0),
#  ('_P_person_mobile.n.01 telephone.n.01_', 0.0),
#  ('_P_person_mobile.n.01_', 0.0),
#  ('_P_person_man.n.01 woman.n.01_', 0.0),
#  ('_P_person_man.n.01 walk.v.01_', 0.0),
#  ('_P_person_man.n.01 stand.v.01_', 0.0),
#  ('_P_person_man.n.01 show.v.01_', 0.0),
#  ('_P_person_man.n.01 pull.v.01_', 0.0),
#  ('_P_person_man.n.01 look.v.01_', 0.0),
#  ('_P_person_man.n.01 lean.v.01_', 0.0),
#  ('_P_person_man.n.01 drink.v.01_', 0.0),
#  ('_P_person_man.n.01 be.v.01_', 0.0),
#  ('_P_person_man.n.01_', 0.0),
#  ('_P_person_male_child.n.01 be.v.01_', 0.0),
#  ('_P_person_male_child.n.01_', 0.0),
#  ('_P_person_love.v.01_', 0.0),
#  ('_P_person_look.v.01 chart.n.01_', 0.0),
#  ('_P_person_look.v.01_', 0.0),
#  ('_P_person_lean.v.01 set.n.01_', 0.0),
#  ('_P_person_lean.v.01 car.n.01_', 0.0),
#  ('_P_person_lean.v.01_', 0.0),
#  ('_P_person_interact.v.01_', 0.0),
#  ('_P_person_icon.n.01_', 0.0),
#  ('_P_person_hallmark.n.01 about.r.03_', 0.0),
#  ('_P_person_hallmark.n.01_', 0.0),
#  ('_P_person_girl.n.01 be.v.01_', 0.0),
#  ('_P_person_girl.n.01_', 0.0),
#  ('_P_person_front.n.01 chart.n.01_', 0.0),
#  ('_P_person_front.n.01_', 0.0),
#  ('_P_person_form.n.01_', 0.0),
#  ('_P_person_following.s.02 poster.n.01_', 0.0),
#  ('_P_person_following.s.02 icon.n.01_', 0.0),
#  ('_P_person_following.s.02_', 0.0),
#  ('_P_person_edge.n.01 city.n.01_', 0.0),
#  ('_P_person_edge.n.01_', 0.0),
#  ('_P_person_drink.v.01 coffee.n.01_', 0.0),
#  ('_P_person_drink.v.01_', 0.0),
#  ('_P_person_computer.n.01_', 0.0),
#  ('_P_person_compass.n.01_', 0.0),
#  ('_P_person_coffee.n.01 airport.n.01_', 0.0),
#  ('_P_person_coffee.n.01_', 0.0),
#  ('_P_person_clean.v.01 computer.n.01_', 0.0),
#  ('_P_person_clean.v.01_', 0.0),
#  ('_P_person_city.n.01_', 0.0),
#  ('_P_person_circle.n.01 compass.n.01_', 0.0),
#  ('_P_person_circle.n.01_', 0.0),
#  ('_P_person_chart.n.01 show.v.01_', 0.0),
#  ('_P_person_chart.n.01 back.n.01_', 0.0),
#  ('_P_person_chart.n.01_', 0.0),
#  ('_P_person_car.n.01_', 0.0),
#  ('_P_person_be.v.01 three.n.01_', 0.0),
#  ('_P_person_be.v.01 stand.v.01_', 0.0),
#  ('_P_person_be.v.01 sit.v.01_', 0.0),
#  ('_P_person_be.v.01 show.v.01_', 0.0),
#  ('_P_person_be.v.01 lean.v.01_', 0.0),
#  ('_P_person_be.v.01 interact.v.01_', 0.0),
#  ('_P_person_be.v.01 clean.v.01_', 0.0),
#  ('_P_person_be.v.01_', 0.0),
#  ('_P_person_back.n.01_', 0.0),
#  ('_P_person_airport.n.01 window.n.01_', 0.0),
#  ('_P_person_airport.n.01_', 0.0),
#  ('_P_person_about.r.03 person.n.01_', 0.0),
#  ('_P_person_about.r.03_', 0.0),
#  ('_P_recreation_wood.n.01_', 0.0),
#  ('_P_recreation_woman.n.01 stand.v.01_', 0.0),
#  ('_P_recreation_woman.n.01 play.n.01_', 0.0),
#  ('_P_recreation_woman.n.01 be.v.01_', 0.0),
#  ('_P_recreation_woman.n.01_', 0.0),
#  ('_P_recreation_window.n.01_', 0.0),
#  ('_P_recreation_web.n.01 icon.n.01_', 0.0),
#  ('_P_recreation_web.n.01_', 0.0),
#  ('_P_recreation_walk.v.01 past.n.01_', 0.0),
#  ('_P_recreation_walk.v.01_', 0.0),
#  ('_P_recreation_three.n.01 hallmark.n.01_', 0.0),
#  ('_P_recreation_three.n.01_', 0.0),
#  ('_P_recreation_telephone.n.01 chart.n.01_', 0.0),
#  ('_P_recreation_telephone.n.01_', 0.0),
#  ('_P_recreation_sword.n.01 rock.n.01_', 0.0),
#  ('_P_recreation_sword.n.01_', 0.0),
#  ('_P_recreation_stand.v.01 front.n.01_', 0.0),
#  ('_P_recreation_stand.v.01 following.s.02_', 0.0),
#  ('_P_recreation_stand.v.01 edge.n.01_', 0.0),
#  ('_P_recreation_stand.v.01_', 0.0),
#  ('_P_recreation_sit.v.01 wood.n.01_', 0.0),
#  ('_P_recreation_sit.v.01_', 0.0),
#  ('_P_recreation_show.v.01 muscle.n.01_', 0.0),
#  ('_P_recreation_show.v.01 love.v.01_', 0.0),
#  ('_P_recreation_show.v.01 form.n.01_', 0.0),
#  ('_P_recreation_show.v.01 chart.n.01_', 0.0),
#  ('_P_recreation_show.v.01_', 0.0),
#  ('_P_recreation_set.n.01 chart.n.01_', 0.0),
#  ('_P_recreation_set.n.01_', 0.0),
#  ('_P_recreation_rock.n.01_', 0.0),
#  ('_P_recreation_pull.v.01 sword.n.01_', 0.0),
#  ('_P_recreation_pull.v.01_', 0.0),
#  ('_P_recreation_poster.n.01 planet.n.01_', 0.0),
#  ('_P_recreation_poster.n.01_', 0.0),
#  ('_P_recreation_play.n.01 circle.n.01_', 0.0),
#  ('_P_recreation_play.n.01_', 0.0),
#  ('_P_recreation_planet.n.01_', 0.0),
#  ('_P_recreation_person.n.01_', 0.0),
#  ('_P_recreation_past.n.01 web.n.01_', 0.0),
#  ('_P_recreation_past.n.01_', 0.0),
#  ('_P_recreation_muscle.n.01_', 0.0),
#  ('_P_recreation_mobile.n.01 telephone.n.01_', 0.0),
#  ('_P_recreation_mobile.n.01_', 0.0),
#  ('_P_recreation_man.n.01 woman.n.01_', 0.0),
#  ('_P_recreation_man.n.01 walk.v.01_', 0.0),
#  ('_P_recreation_man.n.01 stand.v.01_', 0.0),
#  ('_P_recreation_man.n.01 show.v.01_', 0.0),
#  ('_P_recreation_man.n.01 pull.v.01_', 0.0),
#  ('_P_recreation_man.n.01 look.v.01_', 0.0),
#  ('_P_recreation_man.n.01 lean.v.01_', 0.0),
#  ('_P_recreation_man.n.01 drink.v.01_', 0.0),
#  ('_P_recreation_man.n.01 be.v.01_', 0.0),
#  ('_P_recreation_man.n.01_', 0.0),
#  ...]

# %%
# todo - unseen keywords
